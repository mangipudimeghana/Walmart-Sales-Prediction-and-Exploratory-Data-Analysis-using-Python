# %%
## Importing the necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the data set

df=pd.read_csv("Walmart DataSet.csv")

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
# Checking the info of dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df.shape
# Out:
# (6435, 8)

# %%
# Checking for null values

df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
# Checking for duplicate values

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # QUESTION 1 : You are provided with the weekly sales data for their various outlets. Use statistical analysis, EDA, outlier analysis, and handle the missing values to come up with various insights that can give them a clear perspective on the following:

# %% [markdown]
# # Question 'a': If the weekly sales are affected by the unemployment rate, if yes - which stores are suffering the most?

# %%
## Scatter plot on Impact of Unemployment on Sales

sns.scatterplot(x=df.Unemployment, y=df.Weekly_Sales,hue=df.Store, s=80)
plt.xlabel('Unemployment', fontsize=10, labelpad=20)
plt.ylabel('Sales', fontsize=10, labelpad=20)
plt.title('Impact of Unemployment on Sales')
plt.show()

# %% [markdown]
# # Answer to Question 'a':
#
# A higher unemployment index would generally result in a dip in sales as individuals tend to decrease overall spending.
#
# From our scatter plot, it is easier to conclude the following information:
#
# • For the given stores, there seems to be a visible decrease in sales when the unemployment index is higher than 11
#
# • There seems to be a significant drop in sales for stores mentioned in scatter plot, when the
# unemployment index increases
#
# • Highest recorded sales for stores mentioned occur around the unemployment index of 8 to 10;
# this gives ambiguous ideas about the impact of unemployment on sales for each of the store

# %% [markdown]
# # Question 'b':If the weekly sales show a seasonal trend, when and what could be the reason?

# %%
## Plot on Weekly_Sales vs Date

df.plot(x='Date', y='Weekly_Sales',figsize=(20,10),fontsize=20)
plt.xlabel('Date', fontsize=10, labelpad=20)
plt.ylabel('Weekly_Sales', fontsize=10, labelpad=20)
plt.title('Weekly_Sales vs Date')
plt.show()

# %% [markdown]
# # Answer to Question 'b'
#
# From the above plot we can say that weekly_sales shows a seasonal trend.
#
# The highest sales seem to occur in the late spring and early summer (around May and June). This could be due to a variety of factors such as Seasonal changes in consumer behavior, Seasonal variations in product availability, Holidays and events
#
# The lowest sales appear to occur in the winter months (around December and January). This could be due to Decreased consumer spending during the holiday season, Seasonal changes in consumer behavior, Fewer business days

# %% [markdown]
# # Question 'c': Does temperature affect the weekly sales in any manner?

# %%
## Scatter plot on Impact of Temperature on Weekly_Sales

sns.scatterplot(x=df.Temperature, y=df.Weekly_Sales,hue=df.Store, s=40,c='red')
plt.xlabel('Temperature', fontsize=10, labelpad=20)
plt.ylabel('Sales', fontsize=10, labelpad=20)
plt.title('Impact of Temperature on Sales')
plt.show()

# %% [markdown]
# # Answer to Question 'c'
#
# From the above scatter plot we can conclude that:
#
# The highest sales occur for most stores between the range of 40 to 80 degrees Fahrenheit, thus proving the idea that pleasant weather encourages
# higher sales.
#
# Sales are relatively lower for very low and very high temperatures but seem to be adequately high for favorable climate conditions.

# %% [markdown]
# # Question 'd': How is the Consumer Price index affecting the weekly sales of various stores?

# %%
## Scatter plot on Impact of CPI(Consumer Price Index) on Weekly_Sales

sns.scatterplot(x=df.CPI, y=df.Weekly_Sales,hue=df.Store, s=40,c='red')
plt.xlabel('CPI', fontsize=10, labelpad=20)
plt.ylabel('Weekly_sales', fontsize=10, labelpad=20)
plt.title('Impact of CPI on Sales')
plt.show()

# %% [markdown]
# # Answer to Question 'd'
#
# CPI (Consumer Price Index) is defined as the measure of the average change over time in the prices paid by urban consumers for a market basket of consumer goods and services
#
# In our scatter plot above, we can identify three different clusters around different ranges of CPI, while there seems to be no visible relationship between the change in
# CPI and weekly sales for different stores (sales still occur at high CPI rates)

# %% [markdown]
# # Question 'e': Top performing stores according to the historical data.

# %%
## Histogram on Weekly_Sales by Stores

df.hist(column='Weekly_Sales', by='Store',figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'1'}>,
#         <AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>,
#         <AxesSubplot:title={'center':'4'}>,
#         <AxesSubplot:title={'center':'5'}>,
#         <AxesSubplot:title={'center':'6'}>,
#         <AxesSubplot:title={'center':'7'}>],
#        [<AxesSubplot:title={'center':'8'}>,
#         <AxesSubplot:title={'center':'9'}>,
#         <AxesSubplot:title={'center':'10'}>,
#         <AxesSubplot:title={'center':'11'}>,
#         <AxesSubplot:title={'center':'12'}>,
#         <AxesSubplot:title={'center':'13'}>,
#         <AxesSubplot:title={'center':'14'}>],
#        [<AxesSubplot:title={'center':'15'}>,
#         <AxesSubplot:title={'center':'16'}>,
#         <AxesSubplot:title={'center':'17'}>,
#         <AxesSubplot:title={'center':'18'}>,
#         <AxesSubplot:title={'center':'19'}>,
#         <AxesSubplot:title={'center':'20'}>,
#         <AxesSubplot:title={'center':'21'}>],
# ...

# %% [markdown]
# # Answer to Question 'e'
#
# From the above Histograms for all the stores we can say that store numbers 20,4,14,13,2 are top 5 performing stores according to the historical data.

# %% [markdown]
# # Question 'f': The worst performing store, and how significant is the difference between the highest and lowest performing stores

# %%
## Histogram on Weekly_Sales by Stores

df.hist(column='Weekly_Sales', by='Store',figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'1'}>,
#         <AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>,
#         <AxesSubplot:title={'center':'4'}>,
#         <AxesSubplot:title={'center':'5'}>,
#         <AxesSubplot:title={'center':'6'}>,
#         <AxesSubplot:title={'center':'7'}>],
#        [<AxesSubplot:title={'center':'8'}>,
#         <AxesSubplot:title={'center':'9'}>,
#         <AxesSubplot:title={'center':'10'}>,
#         <AxesSubplot:title={'center':'11'}>,
#         <AxesSubplot:title={'center':'12'}>,
#         <AxesSubplot:title={'center':'13'}>,
#         <AxesSubplot:title={'center':'14'}>],
#        [<AxesSubplot:title={'center':'15'}>,
#         <AxesSubplot:title={'center':'16'}>,
#         <AxesSubplot:title={'center':'17'}>,
#         <AxesSubplot:title={'center':'18'}>,
#         <AxesSubplot:title={'center':'19'}>,
#         <AxesSubplot:title={'center':'20'}>,
#         <AxesSubplot:title={'center':'21'}>],
# ...

# %% [markdown]
# # Answer to Question 'f'
#
# From the above Histograms for all the stores we can say that store number '33' is the worst performing store.
# The significant sales difference between the highest and lowest performing stores is 264237580

# %%
col_names=df.columns

# %%
col_names
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
# Plotting box plot for outlier analysis

for col in col_names:
    if df[col].dtype!="object":
        plt.boxplot(df[col])
        plt.xlabel(col)
        plt.ylabel('count')
        plt.show()

# %%
# There are not much outliers so no need to remove any values from dataframe

# %% [markdown]
# # The Feature selection techiques used in this Walmart sales prediction are:
#  1.Correlation
#
#  2.VIF(Variance Inflation Factor)

# %%
# Checking for correlation for all columns

df.corr()
# Out:
#                      Store  Weekly_Sales  Holiday_Flag  Temperature  \
# Store         1.000000e+00     -0.335332 -4.386841e-16    -0.022659
# Weekly_Sales -3.353320e-01      1.000000  3.689097e-02    -0.063810
# Holiday_Flag -4.386841e-16      0.036891  1.000000e+00    -0.155091
# Temperature  -2.265908e-02     -0.063810 -1.550913e-01     1.000000
# Fuel_Price    6.002295e-02      0.009464 -7.834652e-02     0.144982
# CPI          -2.094919e-01     -0.072634 -2.162091e-03     0.176888
# Unemployment  2.235313e-01     -0.106176  1.096028e-02     0.101158
#
#               Fuel_Price       CPI  Unemployment
# Store           0.060023 -0.209492      0.223531
# Weekly_Sales    0.009464 -0.072634     -0.106176
# Holiday_Flag   -0.078347 -0.002162      0.010960
# Temperature     0.144982  0.176888      0.101158
# Fuel_Price      1.000000 -0.170642     -0.034684
# CPI            -0.170642  1.000000     -0.302020
# Unemployment   -0.034684 -0.302020      1.000000

# %%
# Plotting HeatMap 

fig=plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True,cmap="rainbow")
# Out:
# <AxesSubplot:>

# %%
# Importing variance_inflation_factor and preparing list of columns to which VIF needs to be performed

from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in df.columns:
    if((df[col].dtype!='object') & (col!='Weekly_Sales')):
        col_list.append(col)

# %%
col_list
# Out:
# ['Store', 'Holiday_Flag', 'Temperature', 'Fuel_Price', 'CPI', 'Unemployment']

# %%
# Checking for VIF value for all the columns in col_list

X = df[col_list] 
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data['VIF values'] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))] 
vif_data
# Out:
#         feature  VIF values
# 0         Store    4.402614
# 1  Holiday_Flag    1.099768
# 2   Temperature   13.362057
# 3    Fuel_Price   26.734875
# 4           CPI   14.787046
# 5  Unemployment   16.306669

# %%
# Dropping Fuel_Price column as it is having high VIF(26.73)

X=X.drop(['Fuel_Price'], axis = 1)

# %%
# Again checking VIF for remaining columns

vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data['VIF values'] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))] 
vif_data
# Out:
#         feature  VIF values
# 0         Store    4.222253
# 1  Holiday_Flag    1.099532
# 2   Temperature   12.262061
# 3           CPI   11.321203
# 4  Unemployment   12.751568

# %%
# Dropping Unemployment column as it is having high VIF(12.75)

X=X.drop(['Unemployment'], axis = 1)

# %%
# Again checking VIF for remaining columns

vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data['VIF values'] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))] 
vif_data
# Out:
#         feature  VIF values
# 0         Store    3.405015
# 1  Holiday_Flag    1.087194
# 2   Temperature   10.060796
# 3           CPI    9.980430

# %%
# Dropping Temperature column as it is having high VIF(10.06)

X=X.drop(['Temperature'], axis = 1)

# %%
# Again checking VIF for remaining columns

vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data['VIF values'] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))] 
vif_data
# Out:
#         feature  VIF values
# 0         Store    3.145927
# 1  Holiday_Flag    1.072034
# 2           CPI    3.190299

# %%
# Considering only required columns for Predictions

df=df.loc[:,["Store","Holiday_Flag","CPI","Weekly_Sales"]]

# %%
df
# Out:
#       Store  Holiday_Flag         CPI  Weekly_Sales
# 0         1             0  211.096358    1643690.90
# 1         1             1  211.242170    1641957.44
# 2         1             0  211.289143    1611968.17
# 3         1             0  211.319643    1409727.59
# 4         1             0  211.350143    1554806.68
# ...     ...           ...         ...           ...
# 6430     45             0  192.013558     713173.95
# 6431     45             0  192.170412     733455.07
# 6432     45             0  192.327265     734464.36
# 6433     45             0  192.330854     718125.53
# 6434     45             0  192.308899     760281.43
#
# [6435 rows x 4 columns]

# %%
# Fitting data into X and Y

x=df.iloc[:,:-1]
y=df["Weekly_Sales"]

# %%
x
# Out:
#       Store  Holiday_Flag         CPI
# 0         1             0  211.096358
# 1         1             1  211.242170
# 2         1             0  211.289143
# 3         1             0  211.319643
# 4         1             0  211.350143
# ...     ...           ...         ...
# 6430     45             0  192.013558
# 6431     45             0  192.170412
# 6432     45             0  192.327265
# 6433     45             0  192.330854
# 6434     45             0  192.308899
#
# [6435 rows x 3 columns]

# %%
y
# Out:
# 0       1643690.90
# 1       1641957.44
# 2       1611968.17
# 3       1409727.59
# 4       1554806.68
#            ...
# 6430     713173.95
# 6431     733455.07
# 6432     734464.36
# 6433     718125.53
# 6434     760281.43
# Name: Weekly_Sales, Length: 6435, dtype: float64

# %%
# Importing train_test_split and splitting the data into training and testing

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,train_size=0.7, random_state=34)

# %%
x_train
# Out:
#       Store  Holiday_Flag         CPI
# 4370     31             0  215.322931
# 2054     15             0  133.183419
# 1445     11             0  213.911689
# 4229     30             0  215.450863
# 4801     34             0  129.325936
# ...     ...           ...         ...
# 3830     27             0  141.699086
# 5993     42             0  130.737871
# 2538     18             0  137.341103
# 5242     37             1  217.181253
# 3489     25             0  207.188288
#
# [4504 rows x 3 columns]

# %%
# Importing Random Forest Regressor

from sklearn.ensemble import RandomForestRegressor

# %%
# Creating model

r_model = RandomForestRegressor()

# %%
# Training model

r_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
# checking for the predictions

predictions=r_model.predict(x_test)

# %%
predictions
# Out:
# array([1790266.4963, 1281422.651 , 1387935.5061, ...,  923379.3997,
#        1163118.8241,  569411.5816])

# %%
# Importing all from sklearn

from sklearn.metrics import *

# %%
# Checking the R2 score for our model 

r2_score(predictions,y_test)
# Out:
# 0.9195462975660245

# %% [markdown]
# # FORECASTING THE SALES OF WALMART STORES

# %%
# scatter plot between observed and predicted values of weekly sales from Random forest regressor

plt.figure(figsize = (12,6))
plt.title("MODEL : RANDOM FOREST")
plt.xlabel("ORIGINAL VALUES")
plt.ylabel("PREDICTED VALUES")
sns.scatterplot(x = y_test, y = predictions, color='red')
plt.show()

# %%
# Importing Decision Tree Regressor

from sklearn.tree import DecisionTreeRegressor

# %%
# Creating model

d_model = DecisionTreeRegressor()

# %%
# Training model

d_model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
# checking for the predictions

predictions_d=d_model.predict(x_test)

# %%
predictions_d
# Out:
# array([1840491.41, 1287899.41, 1372043.71, ...,  896979.93, 1135577.62,
#         591703.82])

# %%
# Importing all from sklearn

from sklearn.metrics import *

# %%
# Checking the R2 score for our model 

r2_score(predictions_d,y_test)
# Out:
# 0.894747811799123

# %% [markdown]
# # FORECASTING THE SALES OF WALMART STORES

# %%
# scatter plot between observed and predicted values of weekly sales from Decision Tree regressor

plt.figure(figsize = (12,6))
plt.title("MODEL : DECISION TREE")
plt.xlabel("ORIGINAL VALUES")
plt.ylabel("PREDICTED VALUES")
sns.scatterplot(x = y_test, y = predictions_d, color='blue')
plt.show()
